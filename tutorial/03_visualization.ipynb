# %% [markdown]
# # 3. Visualization

# %%
import sys
import os
import importlib
import pickle
import veloev as vev

# You should modify the data path to your local data folder.
os.chdir("/mnt/e/project/Benchmark_velocity/veloev/demo")

# %%
with open("benchmark_info.pkl", "rb") as f:
    benchmark_info = pickle.load(f)

# %% [markdown]
# ## 3.1 Task specific visualization

# %% [markdown]
# ### 3.1.1 Directional consistency
#
# Directional consistency evaluates biological plausibility using cross-boundary directional correctness (CBDir) and in-cluster coherence (ICVCoh).

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='directional', color_palette=my_colors, save_path="directional_summary.png")
# Out:
# Figure saved to directional_summary.png

# %% [markdown]
# ### 3.1.2 Temporal prediction
#
# Temporal precision assesses the accuracy of inferred CLT via cluster temporal ordering (CTO) and temporal Spearman correlation (TSC).

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='temporal', color_palette=my_colors, save_path="temporal_summary.png")
# Out:
# Figure saved to temporal_summary.png

# %% [markdown]
# ### 3.1.3 Negative control robustness
#
# Negative control robustness assesses the ability to avoid spurious dynamics in mature cell populations using the self-transition score (STS) and normalized transition entropy (NTE).

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='negative_control', color_palette=my_colors, save_path="negative_control_summary.png")
# Out:
# Figure saved to negative_control_summary.png

# %% [markdown]
# ### 3.1.4 Simulation
#
# Simulation experiments benchmark these methods using diverse synthetic datasets generated from dynamic models (e.g., ODE models, SDE models, Dyngen), evaluating performance via distance correlation (dCor) and Pearson correlation.

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='simulation', color_palette=my_colors, save_path="simulation_summary.png")
# Out:
# Figure saved to simulation_summary.png

# %% [markdown]
# ### 3.1.5 Sequencing depth (directional)
#
# Sequencing depth stability quantifies performance stability under downsampling noise using stability scores for direction ($\text{S}_\text{CBDir}$) and CLT ($\text{S}_\text{ICVCoh}$).

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='seq_depth_directional', color_palette=my_colors, save_path="seq_depth_directional_summary.png")
# Out:
# Figure saved to seq_depth_directional_summary.png

# %% [markdown]
# ### 3.1.6 Sequencing depth (temporal)
#
# Sequencing depth stability quantifies performance stability under downsampling noise using stability scores for direction ($\text{S}_\text{CTO}$) and CLT ($\text{S}_\text{TSC}$).

# %%
my_colors =  {'bar1': "#5b7e91",'bar2': "#e4ab9b",'rank_low': "#bf794e",'rank_high': "#e6b422"}
vev.viz.plot_task(benchmark_info, plot_type='seq_depth_temporal', color_palette=my_colors, save_path="seq_depth_temporal_summary.png")
# Out:
# Figure saved to seq_depth_temporal_summary.png

# %% [markdown]
# ## 3.2 Overall performance visualization

# %%
my_colors =  {'rank_low': "#bf794e",'rank_high': "#e6b422"}
type_colors = {'directional': '#ae7c58', 'temporal': '#6b6f59', 'negative_control': '#6c848d','seq_depth_directional': '#95859c'}
vev.viz.plot_overall(benchmark_info, include_types=['directional', 'temporal','negative_control','seq_depth_directional'], color_palette=my_colors, type_colors=type_colors, save_path="overall_summary.png")
# Out:
# Figure saved to overall_summary.png

# %%
import sys
import os
import importlib
import pickle
import veloev as vev
os.chdir("/mnt/e/project/Benchmark_velocity/veloev/demo")
# Out:
# <module 'single' from '/mnt/e/project/Benchmark_velocity/veloev/evaluation/single.py'>

# %%
# import scanpy as sc
# import pickle
# import os

# # Define the base path (optional, makes it easier to change later)
# base_path = "/mnt/e/project/Benchmark_velocity/veloev/demo/21_ode_100"

# for fold in range(3):
#     # 1. Read the AnnData file
#     file_path = f"{base_path}/adata_run_velocyto_{fold}.h5ad"
#     print(f"Loading {file_path}...")
#     adata = sc.read(file_path)
    
#     # 2. Extract the true_velocity layer
#     if 'true_velocity' not in adata.layers:
#         print(f"Warning: 'true_velocity' not found in fold {fold}. Skipping.")
#         continue
        
#     true_velocity = adata.layers['true_velocity']

#     # 3. Save to pickle
#     output_filename = f"/mnt/e/project/Benchmark_velocity/veloev/demo/21_ode_100/ground_truth_velocity_{fold}.pkl"
#     with open(output_filename, "wb") as f:
#         pickle.dump(true_velocity, f)
        
#     print(f"Saved {output_filename}")

# print("Done processing all folds.")

# %%
with open("benchmark_info.pkl", "rb") as f:
    benchmark_info = pickle.load(f)

# %%
vev.evl.run_benchmark_evaluation(benchmark_info, base_dir ='./')
# Out:
# 🚀 Starting evaluation: 16 metric calculations across 6 datasets.
# [03_gastrulation_erythroid_sequencing_depth] Stability (tsc): 100%|██████████| 16/16 [01:32<00:00,  5.78s/metric]
# ✅ Evaluation completed.

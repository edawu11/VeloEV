# %% [markdown]
# # 2. Evaluation

# %%
import sys
import os
import importlib
import pickle
import veloev as vev

# You should modify the path to your local data folder.
os.chdir("/mnt/e/project/Benchmark_velocity/veloev/demo")

# %%
with open("benchmark_info.pkl", "rb") as f:
    benchmark_info = pickle.load(f)

# %%
vev.evl.run_evaluation(benchmark_info, base_dir ='./')
# Out:
# 🚀 Starting evaluation: 16 metric calculations across 6 datasets.
# [03_gastrulation_erythroid_sequencing_depth] Stability (tsc): 100%|██████████| 16/16 [01:41<00:00,  6.35s/metric]
# ✅ Evaluation completed.
